# %% [markdown]
# <h3><center>K means Clustering</center></h3>

# %% [markdown]
# <h4>Importing Dependencies</h4>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# <h4>Collecting data and visualization</h4>

# %%
# x=[4,5,10,4,3,11,14,6,10,12]
# y=[21,19,24,17,16,25,24,22,21,21]
import random
x = [random.randrange(1, 500) for i in range(1000)]
y = [random.randrange(1, 500) for i in range(1000)]

# for i in range(1000):
#     x.append(randint(1,800))
#     y.append(randint(1,800))

plt.scatter(x,y)
plt.show()

# %% [markdown]
# <h4>K means Clustering</h4>

# %%
data=list(zip(x,y))
kmeans=KMeans(n_clusters=4)
kmeans.fit(data)

plt.scatter(x,y,c=kmeans.labels_)
plt.show()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# <h4>Getting optimal K</h4>

# %%
inertias=[]

for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias,marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=['name','DSAP','AI'])
display(df)
# Out:
# Empty DataFrame
# Columns: [name, DSAP, AI]
# Index: []

# %%
import random
df['name']=[
    "James", "Mary", "John", "Patricia", "Robert", "Jennifer", "Michael", "Linda", "William", "Elizabeth",
    "David", "Barbara", "Richard", "Susan", "Joseph", "Jessica", "Thomas", "Sarah", "Charles", "Karen",
    "Christopher", "Nancy", "Daniel", "Lisa", "Matthew", "Margaret", "Anthony", "Betty", "Mark", "Sandra",
    "Donald", "Ashley", "Steven", "Kimberly", "Paul", "Emily", "Andrew", "Donna", "Joshua", "Michelle",
    "Kenneth", "Dorothy", "Kevin", "Carol", "Brian", "Amanda", "George", "Melissa", "Edward", "Deborah",
    "Ronald", "Stephanie", "Timothy", "Rebecca", "Jason", "Laura", "Jeffrey", "Helen", "Ryan", "Sharon",
    "Jacob", "Cynthia", "Gary", "Kathleen", "Nicholas", "Amy", "Eric", "Shirley", "Stephen", "Angela",
    "Jonathan", "Anna", "Larry", "Ruth", "Justin", "Brenda", "Scott", "Pamela", "Brandon", "Nicole",
    "Frank", "Katherine", "Benjamin", "Samantha", "Gregory", "Christine", "Raymond", "Catherine", "Samuel", "Virginia",
    "Patrick", "Debra", "Alexander", "Rachel", "Jack", "Janet", "Dennis", "Emma", "Jerry", "Carolyn"
]
df['DSAP']=[random.randrange(1, 80) for i in range(100)]
df['AI']=[random.randrange(1, 80) for i in range(100)]
x=df['DSAP']
y=df['AI']
df.to_csv('data.csv', index=False)
display(df)
# Out:
#         name  DSAP  AI
# 0      James    52  43
# 1       Mary    77  39
# 2       John    52  57
# 3   Patricia    63  42
# 4     Robert    40  42
# ..       ...   ...  ..
# 95     Janet    20  21
# 96    Dennis    56  43
# 97      Emma    21  47
# 98     Jerry    31  60
# 99   Carolyn    72  75
#
# [100 rows x 3 columns]

# %%
inertias=[]
data=list(zip(x,y))
for i in range(1,15):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,15), inertias,marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
data=list(zip(x,y))
kmeans=KMeans(n_clusters=4)
kmeans.fit(data)

plt.scatter(x,y,c=kmeans.labels_)
plt.show()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
clusters=kmeans.predict(data)
df['clusters']=clusters
display(df)
df.to_csv('data.csv', index=False)
# Out:
#         name  DSAP  AI  clusters
# 0      James    52  43         3
# 1       Mary    77  39         3
# 2       John    52  57         3
# 3   Patricia    63  42         3
# 4     Robert    40  42         0
# ..       ...   ...  ..       ...
# 95     Janet    20  21         2
# 96    Dennis    56  43         3
# 97      Emma    21  47         0
# 98     Jerry    31  60         0
# 99   Carolyn    72  75         3
#
# [100 rows x 4 columns]

# %%
# cluster_group_names=[]
# def cluster_group(name):
#     if name in df['name'].values:
#         id = df[df['name'] == name].index[0]
#         val=df.loc[id,'clusters']
#         for index,row in df.iterrows():
#                 if row['clusters'] == val:
#                     cluster_group_names.append(row['name'])
#     else:
#          val=None
#          cluster_group_names.clear() 
#          print(f'There is no name {name} in the Dataframe.')
#     return val,cluster_group_names
        
        


# value,cluster_group_names=cluster_group(input('Enter a name: '))
# print(f'Cluster_value: ', value)
# print(f'Cluster_group_names:', cluster_group_names)


def get_cluster_by_name(name):
     if name in df['name'].values:
        clusterNum= df.loc[df['name'] == name,'clusters'].values[0]
        similar_names = df.loc[df['clusters'] == clusterNum, 'name'].values
        print(f'cluster number is {clusterNum}')
        display(f'names having simlar cluster={clusterNum} are{similar_names}')
     else:
         get_cluster_by_name(input('enter a name again'))

get_cluster_by_name(input('enter a name'))
# Out:
# cluster number is 0
# "names having simlar cluster=0 are['Robert' 'Michael' 'Linda' 'William' 'Anthony' 'Sandra' 'Emily' 'Kevin'\n 'Brian' 'Melissa' 'Stephanie' 'Laura' 'Jeffrey' 'Sharon' 'Jacob'\n 'Cynthia' 'Shirley' 'Nicole' 'Christine' 'Virginia' 'Patrick' 'Debra'\n 'Emma' 'Jerry']"
